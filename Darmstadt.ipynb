# %%
#!pip install html5lib
import requests
import sys
import html5lib
import pandas as pd
import pgeocode

# %% [markdown]
# # 1. Scraping the data and preprocessing

# %%
# get html response from wikipedia
res = requests.get('https://www.postalpinzipcodes.com/Post-Office-Deu-Germany-Darmstadt-Postal-Code-64297-Zip-Code')

# %%
#read html as dataframe, first item is the required table 
df = pd.read_html(res.text)
df = df[1]

# %%
df = df.drop(index=[0,1]).reset_index(drop=True)
df.drop(columns=2, inplace=True)
df.columns=['Name', 'Postal_Code']
df = df.merge(df['Name'].str.split(expand=True)[2], right_index=True ,left_index=True)
df = df.merge(df['Postal_Code'].str.split(expand=True)[2], right_index=True ,left_index=True)
df = df[['2_x', '2_y']]
df.columns=['Neighbourhood', 'Postal_Code']
df
# Out:
#         Neighbourhood Postal_Code
# 0           Darmstadt       64297
# 1          Pfungstadt       64319
# 2           Darmstadt       64285
# 3             Mühltal       64367
# 4           Darmstadt       64295
# 5           Darmstadt       64287
# 6           Darmstadt       64283
# 7   Seeheim-Jugenheim       64342
# 8           Darmstadt       64293
# 9       Ober-Ramstadt       64372
# 10          Griesheim       64347
# 11           Modautal       64397
# 12         Bickenbach       64404
# 13            Roßdorf       64380
# 14          Darmstadt       64289
# 15   Alsbach-Hähnlein       64665
# 16        Weiterstadt       64331
# 17          Darmstadt       64291
# 18        Zwingenberg       64673
# 19          Lautertal       64686

# %%
#Rename Darmstadt with different zip codes as Darmstadt-1, Darmstadt-2 and so on
disc = 1
for index, row in df.iterrows():
    if (row['Neighbourhood'] == 'Darmstadt'):
        df.loc[index,'Neighbourhood'] = 'Darmstadt-' + str(disc)
        disc +=1

# %%
df
# Out:
#         Neighbourhood Postal_Code
# 0         Darmstadt-1       64297
# 1          Pfungstadt       64319
# 2         Darmstadt-2       64285
# 3             Mühltal       64367
# 4         Darmstadt-3       64295
# 5         Darmstadt-4       64287
# 6         Darmstadt-5       64283
# 7   Seeheim-Jugenheim       64342
# 8         Darmstadt-6       64293
# 9       Ober-Ramstadt       64372
# 10          Griesheim       64347
# 11           Modautal       64397
# 12         Bickenbach       64404
# 13            Roßdorf       64380
# 14        Darmstadt-7       64289
# 15   Alsbach-Hähnlein       64665
# 16        Weiterstadt       64331
# 17        Darmstadt-8       64291
# 18        Zwingenberg       64673
# 19          Lautertal       64686

# %%
nm = pgeocode.Nominatim(country='de')

# %%
nm.query_postal_code(64289)
# Out:
# postal_code                               64289
# country code                                 DE
# place_name                            Darmstadt
# state_name                               Hessen
# state_code                                   HE
# county_name          Regierungsbezirk Darmstadt
# county_code                                  64
# community_name    Darmstadt, Wissenschaftsstadt
# community_code                             6411
# latitude                                49.8972
# longitude                                8.6809
# accuracy                                      4
# Name: 0, dtype: object

# %%
lat=[]
lon=[]
for code in df['Postal_Code']:
    res = nm.query_postal_code(code)
    lat.append(res.latitude)
    lon.append(res.longitude)

# %%
#add coordinates
df['Latitude'] = lat
df['Longitude'] = lon
df
# Out:
#         Neighbourhood Postal_Code  Latitude  Longitude
# 0         Darmstadt-1       64297   49.8192     8.6449
# 1          Pfungstadt       64319   49.8056     8.6031
# 2         Darmstadt-2       64285   49.8591     8.6486
# 3             Mühltal       64367   49.8156     8.7081
# 4         Darmstadt-3       64295   49.8611     8.6373
# 5         Darmstadt-4       64287   49.8676     8.6644
# 6         Darmstadt-5       64283   49.8719     8.6484
# 7   Seeheim-Jugenheim       64342   49.7650     8.6519
# 8         Darmstadt-6       64293   49.8875     8.6446
# 9       Ober-Ramstadt       64372   49.8308     8.7489
# 10          Griesheim       64347   49.8609     8.5725
# 11           Modautal       64397   49.7606     8.7208
# 12         Bickenbach       64404   49.7592     8.6175
# 13            Roßdorf       64380   49.8597     8.7617
# 14        Darmstadt-7       64289   49.8972     8.6809
# 15   Alsbach-Hähnlein       64665   49.7386     8.5958
# 16        Weiterstadt       64331   49.9039     8.5887
# 17        Darmstadt-8       64291   49.9111     8.6573
# 18        Zwingenberg       64673   49.7239     8.6108
# 19          Lautertal       64686   49.7258     8.7033

# %%
import folium

# %%
# create map of Toronto using latitude and longitude values

map_darmstadt = folium.Map(location=[49.8875, 8.6446], zoom_start=10)

# add markers to map
for lat, lng, name in zip(df['Latitude'], df['Longitude'], df['Neighbourhood']):
    label = name
    label = folium.Popup(label, parse_html=True)
    color = 'blue'
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color= color,
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_darmstadt)  
    
map_darmstadt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = '1XZFLC0ARIXHRCUD5TPXG2WWAYUWBV4NJOIBF1F31VIGADKA' #Foursquare ID
CLIENT_SECRET = '3JUPYU3IO1EFTGOXBUF3BUEXZQNFMJNJPDOFGBRLUOLDZP4N' #Foursquare Secret
VERSION = '20200707' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1XZFLC0ARIXHRCUD5TPXG2WWAYUWBV4NJOIBF1F31VIGADKA
# CLIENT_SECRET:3JUPYU3IO1EFTGOXBUF3BUEXZQNFMJNJPDOFGBRLUOLDZP4N

# %%
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Darmstadt-1 are 49.8192, 8.6449.

# %%
radius = 500
LIMIT = 100

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f253da78b9c0f54261f0407'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 6,
#   'suggestedBounds': {'ne': {'lat': 49.823700004500004,
#     'lng': 8.651861547791714},
#    'sw': {'lat': 49.8146999955, 'lng': 8.637938452208285}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4c91acf964a52063b626e3',
#        'name': 'Radieschen',
#        'location': {'address': 'Reuterallee 37',
#         'lat': 49.820171239838814,
#         'lng': 8.639814456523967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.820171239838814,
#           'lng': 8.639814456523967}],
#         'distance': 380,
#         'postalCode': '64297',
#         'cc': 'DE',
#         'city': 'Darmstadt',
#         'state': 'Hessen',
#         'country': 'Deutschland',
#         'formattedAddress': ['Reuterallee 37',
#          '64297 Darmstadt',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4c91acf964a52063b626e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6794d88e9120a18150db64',
#        'name': 'Bäckerei Hofmann',
#        'location': {'address': 'Heidelberger Landstr. 227',
#         'lat': 49.819702695449095,
#         'lng': 8.644214792924782,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.819702695449095,
#           'lng': 8.644214792924782}],
#         'distance': 74,
#         'postalCode': '64297',
#         'cc': 'DE',
#         'city': 'Darmstadt',
#         'state': 'Hessen',
#         'country': 'Deutschland',
#         'formattedAddress': ['Heidelberger Landstr. 227',
#          '64297 Darmstadt',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6794d88e9120a18150db64-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f69c90ae4b0f35b73c0df92',
#        'name': 'Bella Sardegna',
#        'location': {'address': 'Heidelberger Landstr. 207',
#         'lat': 49.82085502237481,
#         'lng': 8.64431242376159,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.82085502237481,
#           'lng': 8.64431242376159}],
#         'distance': 189,
#         'postalCode': '64297',
#         'cc': 'DE',
#         'city': 'Darmstadt',
#         'state': 'Hessen',
#         'country': 'Deutschland',
#         'formattedAddress': ['Heidelberger Landstr. 207',
#          '64297 Darmstadt',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f69c90ae4b0f35b73c0df92-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1fa5398b3aa593d8c99d5f',
#        'name': 'H Wartehalle',
#        'location': {'lat': 49.82083817711659,
#         'lng': 8.644255699172266,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.82083817711659,
#           'lng': 8.644255699172266}],
#         'distance': 188,
#         'cc': 'DE',
#         'country': 'Deutschland',
#         'formattedAddress': ['Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1fa5398b3aa593d8c99d5f-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa96fabe4b05f800c79fec9',
#        'name': 'REWE',
#        'location': {'address': 'Heidelberger Landstraße 236-240',
#         'lat': 49.8160890177,
#         'lng': 8.644628965201719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.8160890177,
#           'lng': 8.644628965201719}],
#         'distance': 346,
#         'postalCode': '64297',
#         'cc': 'DE',
#         'neighborhood': 'Eberstadt',
#         'city': 'Darmstadt',
#         'state': 'Hessen',
#         'country': 'Deutschland',
#         'formattedAddress': ['Heidelberger Landstraße 236-240',
#          '64297 Darmstadt',
#          'Deutschland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '566886818'}},
#       'referralId': 'e-0-4fa96fabe4b05f800c79fec9-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3ea323e4b0d8d38330b8fa',
#        'name': 'AKUF GYM',
#        'location': {'address': 'Mühltalstr. 21',
#         'lat': 49.81865171098163,
#         'lng': 8.65094675079006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 49.81865171098163,
#           'lng': 8.65094675079006}],
#         'distance': 438,
#         'postalCode': '64297',
#         'cc': 'DE',
#         'city': 'Darmstadt',
#         'state': 'Hessen',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mühltalstr. 21',
#          '64297 Darmstadt',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3ea323e4b0d8d38330b8fa-5'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        #return categories_list[0]['shortName']
        return categories_list[0]['name']

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
#from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
#import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# C:\Users\lenovo\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                name                     categories        lat       lng
# 0        Radieschen  Vegetarian / Vegan Restaurant  49.820171  8.639814
# 1  Bäckerei Hofmann                         Bakery  49.819703  8.644215
# 2    Bella Sardegna             Italian Restaurant  49.820855  8.644312
# 3      H Wartehalle                       Bus Stop  49.820838  8.644256
# 4              REWE                    Supermarket  49.816089  8.644629

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
tor_venues = getNearbyVenues(names=df['Neighbourhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Darmstadt-1
# Pfungstadt
# Darmstadt-2
# Mühltal
# Darmstadt-3
# Darmstadt-4
# Darmstadt-5
# Seeheim-Jugenheim
# Darmstadt-6
# Ober-Ramstadt
# Griesheim
# Modautal
# Bickenbach
# Roßdorf
# Darmstadt-7
# Alsbach-Hähnlein
# Weiterstadt
# Darmstadt-8
# Zwingenberg
# Lautertal

# %%
tor_venues  = tor_venues[tor_venues['Venue Category'].str.count('(?:^|\W)Restaurant(?:$|\W)')>0]
print(tor_venues.shape)
# Out:
# (42, 7)

# %% [markdown]
# I only care about restaurants so, filter out rest..

# %%
#check number of venues in each neighboirhood
tor_venues.groupby('Neighbourhood').count()['Venue'].sort_values(ascending=False)
# Out:
# Neighbourhood
# Darmstadt-5          20
# Darmstadt-4           4
# Darmstadt-2           4
# Weiterstadt           3
# Seeheim-Jugenheim     2
# Darmstadt-8           2
# Darmstadt-1           2
# Pfungstadt            1
# Ober-Ramstadt         1
# Griesheim             1
# Darmstadt-6           1
# Darmstadt-3           1
# Name: Venue, dtype: int64

# %%
print('There are {} uniques categories.'.format(len(tor_venues['Venue Category'].unique())))
# Out:
# There are 22 uniques categories.

# %%
tor_venues.groupby('Venue Category').count()['Venue'].sort_values(ascending = False)
# Out:
# Venue Category
# German Restaurant                6
# Italian Restaurant               4
# Sushi Restaurant                 4
# Asian Restaurant                 3
# Turkish Restaurant               3
# Falafel Restaurant               2
# French Restaurant                2
# Greek Restaurant                 2
# Vegetarian / Vegan Restaurant    2
# Middle Eastern Restaurant        2
# Indian Restaurant                1
# Mediterranean Restaurant         1
# Mexican Restaurant               1
# Fast Food Restaurant             1
# Restaurant                       1
# Eastern European Restaurant      1
# Doner Restaurant                 1
# Cuban Restaurant                 1
# Comfort Food Restaurant          1
# Australian Restaurant            1
# Tapas Restaurant                 1
# American Restaurant              1
# Name: Venue, dtype: int64

# %%
# one hot encoding
tor_onehot = pd.get_dummies(tor_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
tor_onehot['Neighbourhood'] = tor_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [tor_onehot.columns[-1]] + list(tor_onehot.columns[:-1])
tor_onehot = tor_onehot[fixed_columns]

tor_onehot.head()
# Out:
#    Neighbourhood  American Restaurant  Asian Restaurant  \
# 0    Darmstadt-1                    0                 0
# 2    Darmstadt-1                    0                 0
# 10    Pfungstadt                    0                 0
# 17   Darmstadt-2                    0                 0
# 18   Darmstadt-2                    0                 0
#
#     Australian Restaurant  Comfort Food Restaurant  Cuban Restaurant  \
# 0                       0                        0                 0
# 2                       0                        0                 0
# 10                      0                        0                 0
# 17                      0                        0                 0
# 18                      0                        0                 0
#
#     Doner Restaurant  Eastern European Restaurant  Falafel Restaurant  \
# 0                  0                            0                   0
# 2                  0                            0                   0
# 10                 0                            0                   0
# 17                 0                            0                   0
# 18                 0                            0                   0
#
#     Fast Food Restaurant  French Restaurant  German Restaurant  \
# 0                      0                  0                  0
# 2                      0                  0                  0
# 10                     1                  0                  0
# 17                     0                  1                  0
# 18                     0                  0                  1
#
#     Greek Restaurant  Indian Restaurant  Italian Restaurant  \
# 0                  0                  0                   0
# 2                  0                  0                   1
# 10                 0                  0                   0
# 17                 0                  0                   0
# 18                 0                  0                   0
#
#     Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                          0                   0                          0
# 2                          0                   0                          0
# 10                         0                   0                          0
# 17                         0                   0                          0
# 18                         0                   0                          0
#
#     Restaurant  Sushi Restaurant  Tapas Restaurant  Turkish Restaurant  \
# 0            0                 0                 0                   0
# 2            0                 0                 0                   0
# 10           0                 0                 0                   0
# 17           0                 0                 0                   0
# 18           0                 0                 0                   0
#
#     Vegetarian / Vegan Restaurant
# 0                               1
# 2                               0
# 10                              0
# 17                              0
# 18                              0

# %%
tor_onehot.shape
# Out:
# (42, 23)

# %%
tor_grouped = tor_onehot.groupby('Neighbourhood').mean().reset_index()
tor_grouped
# Out:
#         Neighbourhood  American Restaurant  Asian Restaurant  \
# 0         Darmstadt-1                 0.00               0.0
# 1         Darmstadt-2                 0.00               0.0
# 2         Darmstadt-3                 0.00               1.0
# 3         Darmstadt-4                 0.00               0.0
# 4         Darmstadt-5                 0.05               0.1
# 5         Darmstadt-6                 0.00               0.0
# 6         Darmstadt-8                 0.00               0.0
# 7           Griesheim                 0.00               0.0
# 8       Ober-Ramstadt                 0.00               0.0
# 9          Pfungstadt                 0.00               0.0
# 10  Seeheim-Jugenheim                 0.00               0.0
# 11        Weiterstadt                 0.00               0.0
#
#     Australian Restaurant  Comfort Food Restaurant  Cuban Restaurant  \
# 0                    0.00                     0.00              0.00
# 1                    0.00                     0.00              0.25
# 2                    0.00                     0.00              0.00
# 3                    0.00                     0.25              0.00
# 4                    0.05                     0.00              0.00
# 5                    0.00                     0.00              0.00
# 6                    0.00                     0.00              0.00
# 7                    0.00                     0.00              0.00
# 8                    0.00                     0.00              0.00
# 9                    0.00                     0.00              0.00
# 10                   0.00                     0.00              0.00
# 11                   0.00                     0.00              0.00
#
#     Doner Restaurant  Eastern European Restaurant  Falafel Restaurant  \
# 0                0.0                          0.0                0.00
# 1                0.0                          0.0                0.00
# 2                0.0                          0.0                0.00
# 3                0.0                          0.0                0.00
# 4                0.0                          0.0                0.05
# 5                0.0                          1.0                0.00
# 6                0.5                          0.0                0.00
# 7                0.0                          0.0                1.00
# 8                0.0                          0.0                0.00
# 9                0.0                          0.0                0.00
# 10               0.0                          0.0                0.00
# 11               0.0                          0.0                0.00
#
#     Fast Food Restaurant  French Restaurant  German Restaurant  \
# 0                    0.0               0.00           0.000000
# 1                    0.0               0.25           0.500000
# 2                    0.0               0.00           0.000000
# 3                    0.0               0.00           0.000000
# 4                    0.0               0.05           0.050000
# 5                    0.0               0.00           0.000000
# 6                    0.0               0.00           0.000000
# 7                    0.0               0.00           0.000000
# 8                    0.0               0.00           1.000000
# 9                    1.0               0.00           0.000000
# 10                   0.0               0.00           0.500000
# 11                   0.0               0.00           0.333333
#
#     Greek Restaurant  Indian Restaurant  Italian Restaurant  \
# 0           0.000000               0.00                 0.5
# 1           0.000000               0.00                 0.0
# 2           0.000000               0.00                 0.0
# 3           0.000000               0.25                 0.0
# 4           0.050000               0.00                 0.1
# 5           0.000000               0.00                 0.0
# 6           0.000000               0.00                 0.5
# 7           0.000000               0.00                 0.0
# 8           0.000000               0.00                 0.0
# 9           0.000000               0.00                 0.0
# 10          0.000000               0.00                 0.0
# 11          0.333333               0.00                 0.0
#
#     Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                   0.000000                0.00                        0.0
# 1                   0.000000                0.00                        0.0
# 2                   0.000000                0.00                        0.0
# 3                   0.000000                0.00                        0.0
# 4                   0.000000                0.05                        0.1
# 5                   0.000000                0.00                        0.0
# 6                   0.000000                0.00                        0.0
# 7                   0.000000                0.00                        0.0
# 8                   0.000000                0.00                        0.0
# 9                   0.000000                0.00                        0.0
# 10                  0.000000                0.00                        0.0
# 11                  0.333333                0.00                        0.0
#
#     Restaurant  Sushi Restaurant  Tapas Restaurant  Turkish Restaurant  \
# 0          0.0              0.00              0.00                0.00
# 1          0.0              0.00              0.00                0.00
# 2          0.0              0.00              0.00                0.00
# 3          0.0              0.25              0.25                0.00
# 4          0.0              0.15              0.00                0.15
# 5          0.0              0.00              0.00                0.00
# 6          0.0              0.00              0.00                0.00
# 7          0.0              0.00              0.00                0.00
# 8          0.0              0.00              0.00                0.00
# 9          0.0              0.00              0.00                0.00
# 10         0.5              0.00              0.00                0.00
# 11         0.0              0.00              0.00                0.00
#
#     Vegetarian / Vegan Restaurant
# 0                            0.50
# 1                            0.00
# 2                            0.00
# 3                            0.00
# 4                            0.05
# 5                            0.00
# 6                            0.00
# 7                            0.00
# 8                            0.00
# 9                            0.00
# 10                           0.00
# 11                           0.00

# %%
#Find out most comon venues for each neighborhood
num_top_venues = 5

for hood in tor_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = tor_grouped[tor_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Darmstadt-1----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant   0.5
# 1             Italian Restaurant   0.5
# 2               Asian Restaurant   0.0
# 3             Turkish Restaurant   0.0
# 4               Tapas Restaurant   0.0
#
#
# ----Darmstadt-2----
#                  venue  freq
# 0    German Restaurant  0.50
# 1     Cuban Restaurant  0.25
# 2    French Restaurant  0.25
# 3  American Restaurant  0.00
# 4   Italian Restaurant  0.00
#
#
# ----Darmstadt-3----
#                  venue  freq
# 0     Asian Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Turkish Restaurant   0.0
# 3     Tapas Restaurant   0.0
# 4     Sushi Restaurant   0.0
#
#
# ----Darmstadt-4----
#                      venue  freq
# 0        Indian Restaurant  0.25
# 1  Comfort Food Restaurant  0.25
# 2         Tapas Restaurant  0.25
# 3         Sushi Restaurant  0.25
# 4      American Restaurant  0.00
#
#
# ----Darmstadt-5----
#                        venue  freq
# 0         Turkish Restaurant  0.15
# 1           Sushi Restaurant  0.15
# 2  Middle Eastern Restaurant  0.10
# 3         Italian Restaurant  0.10
# 4           Asian Restaurant  0.10
#
#
# ----Darmstadt-6----
#                          venue  freq
# 0  Eastern European Restaurant   1.0
# 1          American Restaurant   0.0
# 2            Indian Restaurant   0.0
# 3           Turkish Restaurant   0.0
# 4             Tapas Restaurant   0.0
#
#
# ----Darmstadt-8----
#                  venue  freq
# 0     Doner Restaurant   0.5
# 1   Italian Restaurant   0.5
# 2  American Restaurant   0.0
# 3    Indian Restaurant   0.0
# 4   Turkish Restaurant   0.0
#
#
# ----Griesheim----
#                  venue  freq
# 0   Falafel Restaurant   1.0
# 1  American Restaurant   0.0
# 2    Indian Restaurant   0.0
# 3   Turkish Restaurant   0.0
# 4     Tapas Restaurant   0.0
#
#
# ----Ober-Ramstadt----
#                  venue  freq
# 0    German Restaurant   1.0
# 1  American Restaurant   0.0
# 2    Indian Restaurant   0.0
# 3   Turkish Restaurant   0.0
# 4     Tapas Restaurant   0.0
#
#
# ----Pfungstadt----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1   American Restaurant   0.0
# 2     Indian Restaurant   0.0
# 3    Turkish Restaurant   0.0
# 4      Tapas Restaurant   0.0
#
#
# ----Seeheim-Jugenheim----
#                  venue  freq
# 0           Restaurant   0.5
# 1    German Restaurant   0.5
# 2  American Restaurant   0.0
# 3    Indian Restaurant   0.0
# 4   Turkish Restaurant   0.0
#
#
# ----Weiterstadt----
#                       venue  freq
# 0          Greek Restaurant  0.33
# 1  Mediterranean Restaurant  0.33
# 2         German Restaurant  0.33
# 3         Indian Restaurant  0.00
# 4        Turkish Restaurant  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = tor_grouped['Neighbourhood']

for ind in np.arange(tor_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(tor_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#         Neighbourhood          1st Most Common Venue  \
# 0         Darmstadt-1  Vegetarian / Vegan Restaurant
# 1         Darmstadt-2              German Restaurant
# 2         Darmstadt-3               Asian Restaurant
# 3         Darmstadt-4               Tapas Restaurant
# 4         Darmstadt-5               Sushi Restaurant
# 5         Darmstadt-6    Eastern European Restaurant
# 6         Darmstadt-8               Doner Restaurant
# 7           Griesheim             Falafel Restaurant
# 8       Ober-Ramstadt              German Restaurant
# 9          Pfungstadt           Fast Food Restaurant
# 10  Seeheim-Jugenheim              German Restaurant
# 11        Weiterstadt              German Restaurant
#
#             2nd Most Common Venue          3rd Most Common Venue  \
# 0              Italian Restaurant              French Restaurant
# 1                Cuban Restaurant              French Restaurant
# 2   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 3                Sushi Restaurant        Comfort Food Restaurant
# 4              Turkish Restaurant               Asian Restaurant
# 5   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 6              Italian Restaurant  Vegetarian / Vegan Restaurant
# 7   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 8              Turkish Restaurant               Asian Restaurant
# 9   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 10                     Restaurant              French Restaurant
# 11       Mediterranean Restaurant               Greek Restaurant
#
#         4th Most Common Venue          5th Most Common Venue
# 0            Asian Restaurant          Australian Restaurant
# 1          Turkish Restaurant               Asian Restaurant
# 2       Australian Restaurant        Comfort Food Restaurant
# 3           Indian Restaurant  Vegetarian / Vegan Restaurant
# 4   Middle Eastern Restaurant             Italian Restaurant
# 5            Asian Restaurant          Australian Restaurant
# 6           French Restaurant               Asian Restaurant
# 7            Asian Restaurant          Australian Restaurant
# 8       Australian Restaurant        Comfort Food Restaurant
# 9            Asian Restaurant          Australian Restaurant
# 10           Asian Restaurant          Australian Restaurant
# 11          French Restaurant               Asian Restaurant

# %%
# set number of clusters
kclusters = 5

tor_grouped_clustering = tor_grouped.drop('Neighbourhood', 1)

#run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(tor_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 1, 0, 0, 0, 4, 0, 2, 1, 3, 1, 0])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

tor_merged = df
tor_merged = tor_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

##assign an additional cluster for that dont have restarants at all (5 as cluster label)
tor_merged['Cluster Labels'].fillna(5, inplace= True) 
tor_merged['Cluster Labels'] = tor_merged['Cluster Labels'].astype(int,errors ='ignore' )
tor_merged.reset_index(drop=True, inplace=True)
tor_merged # check the last columns!
# Out:
#         Neighbourhood Postal_Code  Latitude  Longitude  Cluster Labels  \
# 0         Darmstadt-1       64297   49.8192     8.6449               0
# 1          Pfungstadt       64319   49.8056     8.6031               3
# 2         Darmstadt-2       64285   49.8591     8.6486               1
# 3             Mühltal       64367   49.8156     8.7081               5
# 4         Darmstadt-3       64295   49.8611     8.6373               0
# 5         Darmstadt-4       64287   49.8676     8.6644               0
# 6         Darmstadt-5       64283   49.8719     8.6484               0
# 7   Seeheim-Jugenheim       64342   49.7650     8.6519               1
# 8         Darmstadt-6       64293   49.8875     8.6446               4
# 9       Ober-Ramstadt       64372   49.8308     8.7489               1
# 10          Griesheim       64347   49.8609     8.5725               2
# 11           Modautal       64397   49.7606     8.7208               5
# 12         Bickenbach       64404   49.7592     8.6175               5
# 13            Roßdorf       64380   49.8597     8.7617               5
# 14        Darmstadt-7       64289   49.8972     8.6809               5
# 15   Alsbach-Hähnlein       64665   49.7386     8.5958               5
# 16        Weiterstadt       64331   49.9039     8.5887               0
# 17        Darmstadt-8       64291   49.9111     8.6573               0
# 18        Zwingenberg       64673   49.7239     8.6108               5
# 19          Lautertal       64686   49.7258     8.7033               5
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant             Italian Restaurant
# 1            Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 2               German Restaurant               Cuban Restaurant
# 3                             NaN                            NaN
# 4                Asian Restaurant  Vegetarian / Vegan Restaurant
# 5                Tapas Restaurant               Sushi Restaurant
# 6                Sushi Restaurant             Turkish Restaurant
# 7               German Restaurant                     Restaurant
# 8     Eastern European Restaurant  Vegetarian / Vegan Restaurant
# 9               German Restaurant             Turkish Restaurant
# 10             Falafel Restaurant  Vegetarian / Vegan Restaurant
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 16              German Restaurant       Mediterranean Restaurant
# 17               Doner Restaurant             Italian Restaurant
# 18                            NaN                            NaN
# 19                            NaN                            NaN
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 0               French Restaurant           Asian Restaurant
# 1              Turkish Restaurant           Asian Restaurant
# 2               French Restaurant         Turkish Restaurant
# 3                             NaN                        NaN
# 4              Turkish Restaurant      Australian Restaurant
# 5         Comfort Food Restaurant          Indian Restaurant
# 6                Asian Restaurant  Middle Eastern Restaurant
# 7               French Restaurant           Asian Restaurant
# 8              Turkish Restaurant           Asian Restaurant
# 9                Asian Restaurant      Australian Restaurant
# 10             Turkish Restaurant           Asian Restaurant
# 11                            NaN                        NaN
# 12                            NaN                        NaN
# 13                            NaN                        NaN
# 14                            NaN                        NaN
# 15                            NaN                        NaN
# 16               Greek Restaurant          French Restaurant
# 17  Vegetarian / Vegan Restaurant          French Restaurant
# 18                            NaN                        NaN
# 19                            NaN                        NaN
#
#             5th Most Common Venue
# 0           Australian Restaurant
# 1           Australian Restaurant
# 2                Asian Restaurant
# 3                             NaN
# 4         Comfort Food Restaurant
# 5   Vegetarian / Vegan Restaurant
# 6              Italian Restaurant
# 7           Australian Restaurant
# 8           Australian Restaurant
# 9         Comfort Food Restaurant
# 10          Australian Restaurant
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16               Asian Restaurant
# 17               Asian Restaurant
# 18                            NaN
# 19                            NaN

# %%
tor_merged
# Out:
#         Neighbourhood Postal_Code  Latitude  Longitude  Cluster Labels  \
# 0         Darmstadt-1       64297   49.8192     8.6449               0
# 1          Pfungstadt       64319   49.8056     8.6031               3
# 2         Darmstadt-2       64285   49.8591     8.6486               1
# 3             Mühltal       64367   49.8156     8.7081               5
# 4         Darmstadt-3       64295   49.8611     8.6373               0
# 5         Darmstadt-4       64287   49.8676     8.6644               0
# 6         Darmstadt-5       64283   49.8719     8.6484               0
# 7   Seeheim-Jugenheim       64342   49.7650     8.6519               1
# 8         Darmstadt-6       64293   49.8875     8.6446               4
# 9       Ober-Ramstadt       64372   49.8308     8.7489               1
# 10          Griesheim       64347   49.8609     8.5725               2
# 11           Modautal       64397   49.7606     8.7208               5
# 12         Bickenbach       64404   49.7592     8.6175               5
# 13            Roßdorf       64380   49.8597     8.7617               5
# 14        Darmstadt-7       64289   49.8972     8.6809               5
# 15   Alsbach-Hähnlein       64665   49.7386     8.5958               5
# 16        Weiterstadt       64331   49.9039     8.5887               0
# 17        Darmstadt-8       64291   49.9111     8.6573               0
# 18        Zwingenberg       64673   49.7239     8.6108               5
# 19          Lautertal       64686   49.7258     8.7033               5
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant             Italian Restaurant
# 1            Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 2               German Restaurant               Cuban Restaurant
# 3                             NaN                            NaN
# 4                Asian Restaurant  Vegetarian / Vegan Restaurant
# 5                Tapas Restaurant               Sushi Restaurant
# 6                Sushi Restaurant             Turkish Restaurant
# 7               German Restaurant                     Restaurant
# 8     Eastern European Restaurant  Vegetarian / Vegan Restaurant
# 9               German Restaurant             Turkish Restaurant
# 10             Falafel Restaurant  Vegetarian / Vegan Restaurant
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 16              German Restaurant       Mediterranean Restaurant
# 17               Doner Restaurant             Italian Restaurant
# 18                            NaN                            NaN
# 19                            NaN                            NaN
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 0               French Restaurant           Asian Restaurant
# 1              Turkish Restaurant           Asian Restaurant
# 2               French Restaurant         Turkish Restaurant
# 3                             NaN                        NaN
# 4              Turkish Restaurant      Australian Restaurant
# 5         Comfort Food Restaurant          Indian Restaurant
# 6                Asian Restaurant  Middle Eastern Restaurant
# 7               French Restaurant           Asian Restaurant
# 8              Turkish Restaurant           Asian Restaurant
# 9                Asian Restaurant      Australian Restaurant
# 10             Turkish Restaurant           Asian Restaurant
# 11                            NaN                        NaN
# 12                            NaN                        NaN
# 13                            NaN                        NaN
# 14                            NaN                        NaN
# 15                            NaN                        NaN
# 16               Greek Restaurant          French Restaurant
# 17  Vegetarian / Vegan Restaurant          French Restaurant
# 18                            NaN                        NaN
# 19                            NaN                        NaN
#
#             5th Most Common Venue
# 0           Australian Restaurant
# 1           Australian Restaurant
# 2                Asian Restaurant
# 3                             NaN
# 4         Comfort Food Restaurant
# 5   Vegetarian / Vegan Restaurant
# 6              Italian Restaurant
# 7           Australian Restaurant
# 8           Australian Restaurant
# 9         Comfort Food Restaurant
# 10          Australian Restaurant
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16               Asian Restaurant
# 17               Asian Restaurant
# 18                            NaN
# 19                            NaN

# %%
# create map
map_clusters = folium.Map(location=[49.8875, 8.6446], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters+1)
ys = [i + x + (i*x)**2 for i in range(kclusters+1)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(tor_merged['Latitude'], tor_merged['Longitude'], tor_merged['Neighbourhood'], tor_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tor_merged
# Out:
#         Neighbourhood Postal_Code  Latitude  Longitude  Cluster Labels  \
# 0         Darmstadt-1       64297   49.8192     8.6449               0
# 1          Pfungstadt       64319   49.8056     8.6031               3
# 2         Darmstadt-2       64285   49.8591     8.6486               1
# 3             Mühltal       64367   49.8156     8.7081               5
# 4         Darmstadt-3       64295   49.8611     8.6373               0
# 5         Darmstadt-4       64287   49.8676     8.6644               0
# 6         Darmstadt-5       64283   49.8719     8.6484               0
# 7   Seeheim-Jugenheim       64342   49.7650     8.6519               1
# 8         Darmstadt-6       64293   49.8875     8.6446               4
# 9       Ober-Ramstadt       64372   49.8308     8.7489               1
# 10          Griesheim       64347   49.8609     8.5725               2
# 11           Modautal       64397   49.7606     8.7208               5
# 12         Bickenbach       64404   49.7592     8.6175               5
# 13            Roßdorf       64380   49.8597     8.7617               5
# 14        Darmstadt-7       64289   49.8972     8.6809               5
# 15   Alsbach-Hähnlein       64665   49.7386     8.5958               5
# 16        Weiterstadt       64331   49.9039     8.5887               0
# 17        Darmstadt-8       64291   49.9111     8.6573               0
# 18        Zwingenberg       64673   49.7239     8.6108               5
# 19          Lautertal       64686   49.7258     8.7033               5
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant             Italian Restaurant
# 1            Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 2               German Restaurant               Cuban Restaurant
# 3                             NaN                            NaN
# 4                Asian Restaurant  Vegetarian / Vegan Restaurant
# 5                Tapas Restaurant               Sushi Restaurant
# 6                Sushi Restaurant             Turkish Restaurant
# 7               German Restaurant                     Restaurant
# 8     Eastern European Restaurant  Vegetarian / Vegan Restaurant
# 9               German Restaurant             Turkish Restaurant
# 10             Falafel Restaurant  Vegetarian / Vegan Restaurant
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 16              German Restaurant       Mediterranean Restaurant
# 17               Doner Restaurant             Italian Restaurant
# 18                            NaN                            NaN
# 19                            NaN                            NaN
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 0               French Restaurant           Asian Restaurant
# 1              Turkish Restaurant           Asian Restaurant
# 2               French Restaurant         Turkish Restaurant
# 3                             NaN                        NaN
# 4              Turkish Restaurant      Australian Restaurant
# 5         Comfort Food Restaurant          Indian Restaurant
# 6                Asian Restaurant  Middle Eastern Restaurant
# 7               French Restaurant           Asian Restaurant
# 8              Turkish Restaurant           Asian Restaurant
# 9                Asian Restaurant      Australian Restaurant
# 10             Turkish Restaurant           Asian Restaurant
# 11                            NaN                        NaN
# 12                            NaN                        NaN
# 13                            NaN                        NaN
# 14                            NaN                        NaN
# 15                            NaN                        NaN
# 16               Greek Restaurant          French Restaurant
# 17  Vegetarian / Vegan Restaurant          French Restaurant
# 18                            NaN                        NaN
# 19                            NaN                        NaN
#
#             5th Most Common Venue
# 0           Australian Restaurant
# 1           Australian Restaurant
# 2                Asian Restaurant
# 3                             NaN
# 4         Comfort Food Restaurant
# 5   Vegetarian / Vegan Restaurant
# 6              Italian Restaurant
# 7           Australian Restaurant
# 8           Australian Restaurant
# 9         Comfort Food Restaurant
# 10          Australian Restaurant
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16               Asian Restaurant
# 17               Asian Restaurant
# 18                            NaN
# 19                            NaN

# %%
tor_merged[tor_merged.columns[[0,4,5,6,7,8,9]]].sort_values('Cluster Labels')
# Out:
#         Neighbourhood  Cluster Labels          1st Most Common Venue  \
# 0         Darmstadt-1               0  Vegetarian / Vegan Restaurant
# 17        Darmstadt-8               0               Doner Restaurant
# 16        Weiterstadt               0              German Restaurant
# 4         Darmstadt-3               0               Asian Restaurant
# 5         Darmstadt-4               0               Tapas Restaurant
# 6         Darmstadt-5               0               Sushi Restaurant
# 7   Seeheim-Jugenheim               1              German Restaurant
# 9       Ober-Ramstadt               1              German Restaurant
# 2         Darmstadt-2               1              German Restaurant
# 10          Griesheim               2             Falafel Restaurant
# 1          Pfungstadt               3           Fast Food Restaurant
# 8         Darmstadt-6               4    Eastern European Restaurant
# 18        Zwingenberg               5                            NaN
# 11           Modautal               5                            NaN
# 12         Bickenbach               5                            NaN
# 13            Roßdorf               5                            NaN
# 14        Darmstadt-7               5                            NaN
# 15   Alsbach-Hähnlein               5                            NaN
# 3             Mühltal               5                            NaN
# 19          Lautertal               5                            NaN
#
#             2nd Most Common Venue          3rd Most Common Venue  \
# 0              Italian Restaurant              French Restaurant
# 17             Italian Restaurant  Vegetarian / Vegan Restaurant
# 16       Mediterranean Restaurant               Greek Restaurant
# 4   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 5                Sushi Restaurant        Comfort Food Restaurant
# 6              Turkish Restaurant               Asian Restaurant
# 7                      Restaurant              French Restaurant
# 9              Turkish Restaurant               Asian Restaurant
# 2                Cuban Restaurant              French Restaurant
# 10  Vegetarian / Vegan Restaurant             Turkish Restaurant
# 1   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 8   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 18                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 3                             NaN                            NaN
# 19                            NaN                            NaN
#
#         4th Most Common Venue          5th Most Common Venue
# 0            Asian Restaurant          Australian Restaurant
# 17          French Restaurant               Asian Restaurant
# 16          French Restaurant               Asian Restaurant
# 4       Australian Restaurant        Comfort Food Restaurant
# 5           Indian Restaurant  Vegetarian / Vegan Restaurant
# 6   Middle Eastern Restaurant             Italian Restaurant
# 7            Asian Restaurant          Australian Restaurant
# 9       Australian Restaurant        Comfort Food Restaurant
# 2          Turkish Restaurant               Asian Restaurant
# 10           Asian Restaurant          Australian Restaurant
# 1            Asian Restaurant          Australian Restaurant
# 8            Asian Restaurant          Australian Restaurant
# 18                        NaN                            NaN
# 11                        NaN                            NaN
# 12                        NaN                            NaN
# 13                        NaN                            NaN
# 14                        NaN                            NaN
# 15                        NaN                            NaN
# 3                         NaN                            NaN
# 19                        NaN                            NaN

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 0, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#    Neighbourhood          1st Most Common Venue  \
# 0    Darmstadt-1  Vegetarian / Vegan Restaurant
# 4    Darmstadt-3               Asian Restaurant
# 5    Darmstadt-4               Tapas Restaurant
# 6    Darmstadt-5               Sushi Restaurant
# 16   Weiterstadt              German Restaurant
# 17   Darmstadt-8               Doner Restaurant
#
#             2nd Most Common Venue          3rd Most Common Venue  \
# 0              Italian Restaurant              French Restaurant
# 4   Vegetarian / Vegan Restaurant             Turkish Restaurant
# 5                Sushi Restaurant        Comfort Food Restaurant
# 6              Turkish Restaurant               Asian Restaurant
# 16       Mediterranean Restaurant               Greek Restaurant
# 17             Italian Restaurant  Vegetarian / Vegan Restaurant
#
#         4th Most Common Venue          5th Most Common Venue
# 0            Asian Restaurant          Australian Restaurant
# 4       Australian Restaurant        Comfort Food Restaurant
# 5           Indian Restaurant  Vegetarian / Vegan Restaurant
# 6   Middle Eastern Restaurant             Italian Restaurant
# 16          French Restaurant               Asian Restaurant
# 17          French Restaurant               Asian Restaurant

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 1, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#        Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 2        Darmstadt-2     German Restaurant      Cuban Restaurant
# 7  Seeheim-Jugenheim     German Restaurant            Restaurant
# 9      Ober-Ramstadt     German Restaurant    Turkish Restaurant
#
#   3rd Most Common Venue  4th Most Common Venue    5th Most Common Venue
# 2     French Restaurant     Turkish Restaurant         Asian Restaurant
# 7     French Restaurant       Asian Restaurant    Australian Restaurant
# 9      Asian Restaurant  Australian Restaurant  Comfort Food Restaurant

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 2, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#    Neighbourhood 1st Most Common Venue          2nd Most Common Venue  \
# 10     Griesheim    Falafel Restaurant  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue
# 10    Turkish Restaurant      Asian Restaurant  Australian Restaurant

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 3, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#   Neighbourhood 1st Most Common Venue          2nd Most Common Venue  \
# 1    Pfungstadt  Fast Food Restaurant  Vegetarian / Vegan Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue
# 1    Turkish Restaurant      Asian Restaurant  Australian Restaurant

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 4, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#   Neighbourhood        1st Most Common Venue          2nd Most Common Venue  \
# 8   Darmstadt-6  Eastern European Restaurant  Vegetarian / Vegan Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue
# 8    Turkish Restaurant      Asian Restaurant  Australian Restaurant

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 5, tor_merged.columns[[0] + list(range(5, tor_merged.shape[1]))]]
# Out:
#        Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 3            Mühltal                   NaN                   NaN
# 11          Modautal                   NaN                   NaN
# 12        Bickenbach                   NaN                   NaN
# 13           Roßdorf                   NaN                   NaN
# 14       Darmstadt-7                   NaN                   NaN
# 15  Alsbach-Hähnlein                   NaN                   NaN
# 18       Zwingenberg                   NaN                   NaN
# 19         Lautertal                   NaN                   NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 3                    NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   NaN
# 19                   NaN                   NaN                   NaN

# %% [markdown]
# # The END
